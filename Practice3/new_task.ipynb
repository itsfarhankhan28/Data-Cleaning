# %%
import pandas as pd

# %%
df = pd.read_excel('./Customer_dataset.xlsx')
df
# Out:
#    Order_ID  Customer_Name Order_Date Product_Category  Quantity   Price  \
# 0       101     John Smith 2023-01-15      Electronics         2  120.50
# 1       102  Alice Johnson 2023-02-10         Clothing         1   45.00
# 2       103      Bob Brown 2023-03-05   Home & Kitchen         3   89.99
# 3       104      Eva Green 2023-04-12      Electronics         1  250.00
# 4       105  Charlie Davis 2023-05-20         Clothing         2   75.00
# 5       106            NaN 2023-06-15   Home & Kitchen         4  120.00
# 6       107     Grace Hall 2023-07-01      Electronics         1  500.00
# 7       108     Henry King 2023-08-10         Clothing         3   90.00
# 8       109      Irene Lee 2023-09-05   Home & Kitchen         2   60.00
# 9       110    Frank White 2023-10-12      Electronics         1  300.00
#
#    Discount Payment_Method Delivery_Status
# 0        10    Credit Card       Delivered
# 1         5         PayPal         Pending
# ...

# %%
df = df.fillna('Unknown')
df
# Out:
#    Order_ID  Customer_Name Order_Date Product_Category  Quantity   Price  \
# 0       101     John Smith 2023-01-15      Electronics         2  120.50
# 1       102  Alice Johnson 2023-02-10         Clothing         1   45.00
# 2       103      Bob Brown 2023-03-05   Home & Kitchen         3   89.99
# 3       104      Eva Green 2023-04-12      Electronics         1  250.00
# 4       105  Charlie Davis 2023-05-20         Clothing         2   75.00
# 5       106        Unknown 2023-06-15   Home & Kitchen         4  120.00
# 6       107     Grace Hall 2023-07-01      Electronics         1  500.00
# 7       108     Henry King 2023-08-10         Clothing         3   90.00
# 8       109      Irene Lee 2023-09-05   Home & Kitchen         2   60.00
# 9       110    Frank White 2023-10-12      Electronics         1  300.00
#
#    Discount Payment_Method Delivery_Status
# 0        10    Credit Card       Delivered
# 1         5         PayPal         Pending
# ...

# %%
df.head()
# Out:
#    Order_ID  Customer_Name Order_Date Product_Category  Quantity   Price  \
# 0       101     John Smith 2023-01-15      Electronics         2  120.50
# 1       102  Alice Johnson 2023-02-10         Clothing         1   45.00
# 2       103      Bob Brown 2023-03-05   Home & Kitchen         3   89.99
# 3       104      Eva Green 2023-04-12      Electronics         1  250.00
# 4       105  Charlie Davis 2023-05-20         Clothing         2   75.00
#
#    Discount Payment_Method Delivery_Status
# 0        10    Credit Card       Delivered
# 1         5         PayPal         Pending
# 2         0           Cash         Shipped
# 3        20    Credit Card       Delivered
# 4        15        Unknown         Pending

# %%
df.describe()
# Out:
#         Order_ID           Order_Date   Quantity       Price   Discount
# count   10.00000                   10  10.000000   10.000000  10.000000
# mean   105.50000  2023-05-26 12:00:00   2.000000  165.049000  14.000000
# min    101.00000  2023-01-15 00:00:00   1.000000   45.000000   0.000000
# 25%    103.25000  2023-03-14 12:00:00   1.000000   78.747500   5.000000
# 50%    105.50000  2023-06-02 00:00:00   2.000000  105.000000  10.000000
# 75%    107.75000  2023-07-31 00:00:00   2.750000  217.625000  18.750000
# max    110.00000  2023-10-12 00:00:00   4.000000  500.000000  50.000000
# std      3.02765                  NaN   1.054093  143.935451  15.055453

# %%
# unique_items = df['Product_Category'].unique()
# print(unique_items)

unique_items = df['Payment_Method'].unique()
print(unique_items)
# Out:
# ['Credit Card' 'PayPal' 'Cash' 'Unknown']

# %%
df['Product_Category'] = df['Product_Category'].str.title()
df
# Out:
#    Order_ID  Customer_Name Order_Date Product_Category  Quantity   Price  \
# 0       101     John Smith 2023-01-15      Electronics         2  120.50
# 1       102  Alice Johnson 2023-02-10         Clothing         1   45.00
# 2       103      Bob Brown 2023-03-05   Home & Kitchen         3   89.99
# 3       104      Eva Green 2023-04-12      Electronics         1  250.00
# 4       105  Charlie Davis 2023-05-20         Clothing         2   75.00
# 5       106        Unknown 2023-06-15   Home & Kitchen         4  120.00
# 6       107     Grace Hall 2023-07-01      Electronics         1  500.00
# 7       108     Henry King 2023-08-10         Clothing         3   90.00
# 8       109      Irene Lee 2023-09-05   Home & Kitchen         2   60.00
# 9       110    Frank White 2023-10-12      Electronics         1  300.00
#
#    Discount Payment_Method Delivery_Status
# 0        10    Credit Card       Delivered
# 1         5         PayPal         Pending
# ...

# %%
# df[['Order_Year']] = df['Order_Date'].apply(lambda x: x.date().year)
df['Order_Yaer'] = df['Order_Date'].apply(lambda x: x.date().year)
df
# Out:
#    Order_ID  Customer_Name Order_Date Product_Category  Quantity   Price  \
# 0       101     John Smith 2023-01-15      Electronics         2  120.50
# 1       102  Alice Johnson 2023-02-10         Clothing         1   45.00
# 2       103      Bob Brown 2023-03-05   Home & Kitchen         3   89.99
# 3       104      Eva Green 2023-04-12      Electronics         1  250.00
# 4       105  Charlie Davis 2023-05-20         Clothing         2   75.00
# 5       106        Unknown 2023-06-15   Home & Kitchen         4  120.00
# 6       107     Grace Hall 2023-07-01      Electronics         1  500.00
# 7       108     Henry King 2023-08-10         Clothing         3   90.00
# 8       109      Irene Lee 2023-09-05   Home & Kitchen         2   60.00
# 9       110    Frank White 2023-10-12      Electronics         1  300.00
#
#    Discount Payment_Method Delivery_Status  Order_Yaer
# 0        10    Credit Card       Delivered        2023
# ...

# %%
df['Order_Month'] = df['Order_Date'].apply(lambda x: x.date().month)
df
# Out:
#    Order_ID  Customer_Name Order_Date Product_Category  Quantity   Price  \
# 0       101     John Smith 2023-01-15      Electronics         2  120.50
# 1       102  Alice Johnson 2023-02-10         Clothing         1   45.00
# 2       103      Bob Brown 2023-03-05   Home & Kitchen         3   89.99
# 3       104      Eva Green 2023-04-12      Electronics         1  250.00
# 4       105  Charlie Davis 2023-05-20         Clothing         2   75.00
# 5       106        Unknown 2023-06-15   Home & Kitchen         4  120.00
# 6       107     Grace Hall 2023-07-01      Electronics         1  500.00
# 7       108     Henry King 2023-08-10         Clothing         3   90.00
# 8       109      Irene Lee 2023-09-05   Home & Kitchen         2   60.00
# 9       110    Frank White 2023-10-12      Electronics         1  300.00
#
#    Discount Payment_Method Delivery_Status  Order_Yaer  Order_Month
# 0        10    Credit Card       Delivered        2023            1
# ...

# %%
filtered_month = df[df['Order_Date'].apply(lambda x: x.date().month == 3)]
filtered_month
# Out:
#    Order_ID Customer_Name Order_Date Product_Category  Quantity  Price  \
# 2       103     Bob Brown 2023-03-05   Home & Kitchen         3  89.99
#
#    Discount Payment_Method Delivery_Status  Order_Yaer  Order_Month
# 2         0           Cash         Shipped        2023            3
